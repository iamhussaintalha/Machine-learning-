# %% [markdown]
# # FIFTH DEGREE REGRESSION MODEL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

trn_d= pd.read_csv('trainRegression.csv')
trn_d.head()
# Out:
#       X       R
# 0  0.01 -0.2730
# 1  0.02 -0.1170
# 2  0.03 -0.3090
# 3  0.04  0.0306
# 4  0.05 -0.0802

# %%
trnx= np.array(trn_d['X']) 
trny= np.array(trn_d['R'])

# %%
A=np.array([[len(trnx),sum(trnx),sum(trnx**2),sum(trnx**3),sum(trnx**4),sum(trnx**5)],[sum(trnx),sum(trnx**2),sum(trnx**3),sum(trnx**4),sum(trnx**5),sum(trnx**6)],[sum(trnx**2),sum(trnx**3),sum(trnx**4),sum(trnx**5),sum(trnx**6),sum(trnx**7)],[sum(trnx**3),sum(trnx**4),sum(trnx**5),sum(trnx**6),sum(trnx**7),sum(trnx**8)],[sum(trnx**4),sum(trnx**5),sum(trnx**6),sum(trnx**7),sum(trnx**8),sum(trnx**9)],[sum(trnx**5),sum(trnx**6),sum(trnx**7),sum(trnx**8),sum(trnx**9),sum(trnx**10)]])
A
# Out:
# array([[2.83000000e+02, 4.44950000e+02, 9.32746500e+02, 2.19978103e+03,
#         5.53385258e+03, 1.45013383e+04],
#        [4.44950000e+02, 9.32746500e+02, 2.19978103e+03, 5.53385258e+03,
#         1.45013383e+04, 3.90864884e+04],
#        [9.32746500e+02, 2.19978103e+03, 5.53385258e+03, 1.45013383e+04,
#         3.90864884e+04, 1.07548336e+05],
#        [2.19978103e+03, 5.53385258e+03, 1.45013383e+04, 3.90864884e+04,
#         1.07548336e+05, 3.00624107e+05],
#        [5.53385258e+03, 1.45013383e+04, 3.90864884e+04, 1.07548336e+05,
#         3.00624107e+05, 8.50829605e+05],
#        [1.45013383e+04, 3.90864884e+04, 1.07548336e+05, 3.00624107e+05,
#         8.50829605e+05, 2.43237118e+06]])

# %%
B=np.array([[sum(trny)],[sum(trnx*trny)],[sum(trny*(trnx**2))],[sum(trny*(trnx**3))],[sum(trny*(trnx**4))],[sum(trny*(trnx**5))]])
B
# Out:
# array([[ 1.39087000e+00],
#        [-1.26641429e+02],
#        [-3.78875690e+02],
#        [-9.52324104e+02],
#        [-2.30897053e+03],
#        [-5.57500637e+03]])

# %%
A_inverse=np.linalg.inv(A)
A_inverse
# Out:
# array([[  0.12852024,  -0.71628738,   1.21560502,  -0.8700334 ,
#           0.27671084,  -0.0322663 ],
#        [ -0.71628738,   5.30430783, -10.11254655,   7.71408933,
#          -2.55435718,   0.30625647],
#        [  1.21560502, -10.11254655,  20.55290692, -16.32644783,
#           5.55954179,  -0.68036239],
#        [ -0.8700334 ,   7.71408933, -16.32644783,  13.33745686,
#          -4.63586972,   0.57629216],
#        [  0.27671084,  -2.55435718,   5.55954179,  -4.63586972,
#           1.63682583,  -0.20601172],
#        [ -0.0322663 ,   0.30625647,  -0.68036239,   0.57629216,
#          -0.20601172,   0.02619001]])

# %%
i=np.dot(A_inverse,B)
i
# Out:
# array([[-0.15135453],
#        [ 2.89713972],
#        [-0.36242336],
#        [-2.76674175],
#        [ 1.48161173],
#        [-0.20822932]])

# %%
Predtrn=i[0]+i[1]*trnx+i[2]*(trnx**2)+i[3]*(trnx**3)+i[4]*(trnx**4)+i[5]*(trnx**5)
plt.plot(trnx,trny)
plt.plot(trnx,Predtrn)

# %%
#MSR FOR TRAINING DATA
sum(np.square(trny-Predtrn))/len(trnx)
# Out:
# 0.038521557399982864

# %%
tst_d= pd.read_csv('testRegression.csv.')
tstx=tst_d['X']
tsty=tst_d['R']

# %%
Predtst= i[0]+i[1]*tstx+i[2]*(tstx**2)+i[3]*(tstx**3)+i[4]*(tstx**4)+i[5]*(tstx**5)
plt.plot(tstx,tsty)
plt.plot(tstx,Predtst)

# %%
#MSR FOR TESTING DATA 
sum(np.square((tsty)-(Predtst)))/len(tstx)
# Out:
# 0.044206774269472025
